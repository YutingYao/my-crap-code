# %% [markdown]
# # 异常路段

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 这个原因是缓冲区设置不当，已重新输出解决

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 桥、高架等样本，轨迹点无法被正确分类，删除

# %% [markdown]
# 低速样本【桂元路】
# 限速20,但是出现很多超速
# ![image.png](attachment:image.png)

# %% [markdown]
# 查看地图，该路位于校内
# ![image.png](attachment:image.png)

# %% [markdown]
# 定义平均速度大于限速为异常样本路段，发现主要集中在低速路段
# ![image.png](attachment:image.png)

# %% [markdown]
# 问题样本计数
# ![image.png](attachment:image.png)

# %% [markdown]
# 样本错误率排序（按fclass）
# ![image.png](attachment:image.png)

# %% [markdown]
# 样本错误率排序（按maxspeed）
# ![image.png](attachment:image.png)

# %% [markdown]
# 样本错误率排序（按numofLines）
# ![image.png](attachment:image.png)
